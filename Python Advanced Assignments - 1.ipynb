# %% [markdown]
# ### Question 1
#
# What is the purpose of Python&#39;s OOP?

# %% [markdown]
# ### Answer 1
#
# Object Oriented Programming (OOP) is method of structuring a program by bundling related properties and behaviour into individual objects.
#
# OOP is procedural programming, which structures a program like a recipe. In that it provides set of steps, in the form of functions and code blocks, that flow sequentially in order to complete a task.
#
# Objects are centre of OOP in Python.

# %% [markdown]
# ### Question 2
#
# Where does an inheritance search look for an attribute?

# %% [markdown]
# ### Answer 2
#
# Attribute inheritance is a property that inherits all attribute values and all relationship instances of the super type to its entities of subtype.
#
# An Inheritance search looks for an attribute in its super class.

# %% [markdown]
# ### Question 3
#
# How do you distinguish between a class object and an instance object?

# %% [markdown]
# ### Answer 3
#
# Instance variables are used for data that is unique to a particular instance, Whereas Class variables are that are shared by all instances of a class.

# %% [markdown]
# ### Question 4
#
# What makes the first argument in a class’s method function special?

# %% [markdown]
# ### Answer 4
#
# `SELF` is the first arguments in a class. It acts as an pointer in the class.
#
# By using "self" keyword we can access the attributes and methods of the class in python.
#
# It binds the attributes with the given arguments.
#
# The reason you need to use self. is because Python does not use the @ syntax to refer to instance attributes. Python decided to do methods in a way that makes the instance to which the method belongs be passed automatically, but not received automatically: the first parameter of methods is the instance the method is called on.

# %% [markdown]
# ### Question 5
#
# What is the purpose of the __init__ method?

# %% [markdown]
# ### Answer 5
#
# `__init__` is a reserved method in python classes. It is called as constructor in OOP.
#
# This method is called when an object is created from a class and it allows the class to initialize the attributes of a class.

# %% [markdown]
# ### Question 6
#
# What is the process for creating a class instance?

# %% [markdown]
# ### Answer 6
#
# To create a class instance, need to call the class using class name and pass the arguments whatever `__init__` method accepts.

# %% [markdown]
# ### Question 7
#
# What is the process for creating a class?

# %% [markdown]
# ### Answer 7
#
# To create a class we use `class` as keyword. Class can be defined in a simple string of code.
#
# Then need to create functions of the class by initializing and then passing self and other arguments.

# %% [markdown]
# ### Question 8
#
# How would you define the superclasses of a class?

# %% [markdown]
# ### Answer 8
#
# The class from which a class inherits is called parent or a superclass. It uses a keyword super to define a superclass.
